# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Porcino

# %%
a=pd.read_excel('data-20230708/porcino.xlsx')

# %%
a
# Out:
#         ID  Espesor Lomo\n  (m.m)  Porcentaje Magro\n CM (%)    Sexo  \
# 0      NaN                    NaN                        NaN     NaN
# 1      1.0                   64.4                       55.8   MACHO
# 2      2.0                   64.0                       57.9   MACHO
# 3      3.0                   56.4                       58.8   MACHO
# 4      4.0                   69.2                       54.6   MACHO
# ..     ...                    ...                        ...     ...
# 496  496.0                   80.8                       54.5  HEMBRA
# 497  497.0                   73.2                       55.6  HEMBRA
# 498  498.0                   66.4                       56.1  HEMBRA
# 499  499.0                   70.0                       57.4  HEMBRA
# 500  500.0                   73.6                       56.5  HEMBRA
#
#             Region Calidad de la carne  Peso Canal Caliente \n (PCC- Kg)  \
# ...

# %% [markdown]
# #### porcino hembra-calidad buena

# %%
m=a.loc[a.Sexo=='HEMBRA']
n=m.loc[m['Calidad de la carne']=='Buena']
n.head(20)
# Out:
#         ID  Espesor Lomo\n  (m.m)  Porcentaje Magro\n CM (%)    Sexo  \
# 344  344.0                   54.8                       48.3  HEMBRA
# 351  351.0                   50.0                       49.3  HEMBRA
# 373  373.0                   55.6                       49.8  HEMBRA
# 383  383.0                   60.8                       47.2  HEMBRA
#
#          Region Calidad de la carne  Peso Canal Caliente \n (PCC- Kg)  \
# 344   O´Higgins               Buena                              76.9
# 351   O´Higgins               Buena                              73.9
# 373  Valparaiso               Buena                              77.4
# 383   O´Higgins               Buena                             115.0
#
#      Peso Canal Refrigerada (PCR - Kg)
# 344                               71.9
# 351                               73.6
# 373                               72.8
# 383                              108.7

# %% [markdown]
# #### porcinos machos-total

# %%
l=a.loc[a.Sexo=='MACHO']
l.shape
# Out:
# (379, 8)

# %% [markdown]
#  ### porcinos hembra-calidad estandar

# %%
m=a.loc[a.Sexo=='HEMBRA']
n=m.loc[m['Calidad de la carne']=='Estandar']
n.shape
# Out:
# (27, 8)

# %% [markdown]
# ### porcinos hembras- de una region especifica

# %%
m=a.loc[a.Sexo=='HEMBRA']
n=m.loc[m['Region']=='O´Higgins']
n.shape
# Out:
# (106, 8)

# %% [markdown]
# ### procinos hembra de una region especifica

# %%
m=a.loc[a.Sexo=='HEMBRA']
n=m.loc[m['Region']=='Metropolitana']
n.shape
# Out:
# (4, 8)

# %% [markdown]
# ### porcinos machos de una region especifica

# %%
m=a.loc[a.Sexo=='MACHO']
n=m.loc[m['Region']=='O´Higgins']
n.shape
# Out:
# (308, 8)

# %% [markdown]
# # archivo music

# %%
b=pd.read_csv('data-20230708/music.csv')

# %%
b
# Out:
#      Year     Format  Revenue [m$]
# 0    1973        DVD           0.0
# 1    1973      Other           0.0
# 2    1973      Tapes        2941.0
# 3    1973   Download           0.0
# 4    1973  Streaming           0.0
# ..    ...        ...           ...
# 379  2020   Download         653.0
# 380  2020  Streaming       10075.0
# 381  2020   Cassette           0.0
# 382  2020      Vinyl         626.0
# 383  2020         CD         484.0
#
# [384 rows x 3 columns]

# %% [markdown]
# ### ordenamos de mayor a menor segun m$

# %%
r=b.sort_values('Revenue [m$]',ascending=False)
r.head(20)
# Out:
#      Year     Format  Revenue [m$]
# 215  1999         CD       20255.0
# 223  2000         CD       20075.0
# 231  2001         CD       18982.0
# 207  1998         CD       18465.0
# 239  2002         CD       17355.0
# 191  1996         CD       16691.0
# 199  1997         CD       16428.0
# 183  1995         CD       16113.0
# 247  2003         CD       15888.0
# 255  2004         CD       15726.0
# 175  1994         CD       14880.0
# 263  2005         CD       13969.0
# 271  2006         CD       12049.0
# 167  1993         CD       11744.0
# 46   1978      Vinyl       10851.0
# 38   1977      Vinyl       10422.0
# 380  2020  Streaming       10075.0
# 159  1992         CD        9909.0
# 279  2007         CD        9324.0
# 372  2019  Streaming        8992.0

# %% [markdown]
# ### ordenamos solo del 2019

# %%
m=b.loc[b.Year==2019]
k=m.sort_values('Revenue [m$]',ascending=False)
k.head(20)
# Out:
#      Year     Format  Revenue [m$]
# 372  2019  Streaming        8992.0
# 371  2019   Download         810.0
# 375  2019         CD         639.0
# 374  2019      Vinyl         492.0
# 369  2019      Other         333.0
# 368  2019        DVD           1.3
# 370  2019      Tapes           0.0
# 373  2019   Cassette           0.0

# %% [markdown]
# ## el valor mas alto de m$

# %%
b=b.sort_values('Revenue [m$]',ascending=False)
b.head(20)
# Out:
#      Year     Format  Revenue [m$]
# 215  1999         CD       20255.0
# 223  2000         CD       20075.0
# 231  2001         CD       18982.0
# 207  1998         CD       18465.0
# 239  2002         CD       17355.0
# 191  1996         CD       16691.0
# 199  1997         CD       16428.0
# 183  1995         CD       16113.0
# 247  2003         CD       15888.0
# 255  2004         CD       15726.0
# 175  1994         CD       14880.0
# 263  2005         CD       13969.0
# 271  2006         CD       12049.0
# 167  1993         CD       11744.0
# 46   1978      Vinyl       10851.0
# 38   1977      Vinyl       10422.0
# 380  2020  Streaming       10075.0
# 159  1992         CD        9909.0
# 279  2007         CD        9324.0
# 372  2019  Streaming        8992.0

# %% [markdown]
# ## sacamos solo nivyl y los ordenamos de mayo a menor segun su m$

# %%
m=b.loc[b.Format=='Vinyl']
b=m.sort_values('Revenue [m$]',ascending=False)
b.head(20)
# Out:
#      Year Format  Revenue [m$]
# 46   1978  Vinyl       10851.0
# 38   1977  Vinyl       10422.0
# 30   1976  Vinyl        8679.0
# 54   1979  Vinyl        8594.0
# 6    1973  Vinyl        8371.0
# 22   1975  Vinyl        8161.0
# 14   1974  Vinyl        8137.0
# 62   1980  Vinyl        7695.0
# 70   1981  Vinyl        7397.0
# 78   1982  Vinyl        5922.0
# 86   1983  Vinyl        5089.0
# 94   1984  Vinyl        4602.0
# 102  1985  Vinyl        3756.0
# 110  1986  Vinyl        2860.0
# 118  1987  Vinyl        2270.0
# 126  1988  Vinyl        1559.0
# 134  1989  Vinyl         703.0
# 382  2020  Vinyl         626.0
# 374  2019  Vinyl         492.0
# 366  2018  Vinyl         438.0

# %%
j=b.loc[b.Format=='Download']
m=j.sort_values('Revenue [m$]', ascending=False)
m
# Out:
#      Year    Format  Revenue [m$]
# 315  2012  Download        3235.0
# 323  2013  Download        3136.0
# 307  2011  Download        3021.0
# 331  2014  Download        2719.0
# 299  2010  Download        2665.0
# 339  2015  Download        2464.0
# 291  2009  Download        2361.0
# 283  2008  Download        2054.0
# 347  2016  Download        1930.0
# 275  2007  Download        1669.0
# 355  2017  Download        1412.0
# 267  2006  Download        1125.0
# 363  2018  Download        1038.0
# 371  2019  Download         810.0
# 259  2005  Download         666.0
# 379  2020  Download         653.0
# 251  2004  Download         251.0
# 11   1974  Download           0.0
# 243  2003  Download           0.0
# 235  2002  Download           0.0
# 227  2001  Download           0.0
# 219  2000  Download           0.0
# 211  1999  Download           0.0
# 203  1998  Download           0.0
# 3    1973  Download           0.0
# 187  1996  Download           0.0
# ...

# %% [markdown]
# # Titanic

# %%
c=pd.read_csv('data-20230708/titanic.csv')

# %%
c
# Out:
#      Count  PassengerId  Survived  Pclass  \
# 0        1            1      Died       3
# 1        1            2  Survived       1
# 2        1            3  Survived       3
# 3        1            4  Survived       1
# 4        1            5      Died       3
# ..     ...          ...       ...     ...
# 886      1          887      Died       2
# 887      1          888  Survived       1
# 888      1          889      Died       3
# 889      1          890  Survived       1
# 890      1          891      Died       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# ## mujeres con 38 años que ayan muerto

# %%
m=c.loc[c.Sex=='female']
n=m.loc[m['Age']==38]
h=n.loc[m['Survived']=='Died']
h.head(20)
# Out:
#      Count  PassengerId  Survived  Pclass  \
# 1        1            2  Survived       1
# 25       1           26  Survived       3
# 61       1           62  Survived       1
# 357      1          358      Died       2
# 716      1          717  Survived       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 61                                 Icard, Miss. Amelie  female  38.0      0
# 357                          Funk, Miss. Annie Clemmer  female  38.0      0
# 716                      Endres, Miss. Caroline Louise  female  38.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 1        0  PC 17599   71.2833   C85        C
# 25       5    347077   31.3875   NaN        S
# 61       0    113572   80.0000   B28      NaN
# 357      0    237671   13.0000   NaN        S
# ...

# %% [markdown]
# ## numero de personas con 38 que habian en el titanic

# %%
k=c.loc[c['Age']==38]

k
k.shape
# Out:
# (11, 13)

# %% [markdown]
# ## numero de personas de 38 años que hayan sobrevivido

# %%
n=c.loc[c['Age']==38]

s=n.loc[n['Survived']=='Survived']
s.shape
# Out:
# (5, 13)

# %% [markdown]
# ## mujeres que hayan muerto

# %%
n=c.loc[c['Sex']=='female']

s=n.loc[n['Survived']=='Died']
s.shape
# Out:
# (81, 13)

# %% [markdown]
# ## mujeres de 38 que sobrevivieron

# %%
n=c.loc[c['Age']==38]

s=n.loc[n['Survived']=='Survived']
s
# Out:
#      Count  PassengerId  Survived  Pclass  \
# 1        1            2  Survived       1
# 25       1           26  Survived       3
# 61       1           62  Survived       1
# 224      1          225  Survived       1
# 716      1          717  Survived       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 61                                 Icard, Miss. Amelie  female  38.0      0
# 224                       Hoyt, Mr. Frederick Maxfield    male  38.0      1
# 716                      Endres, Miss. Caroline Louise  female  38.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 1        0  PC 17599   71.2833   C85        C
# 25       5    347077   31.3875   NaN        S
# 61       0    113572   80.0000   B28      NaN
# 224      0     19943   90.0000   C93        S
# ...

# %% [markdown]
# # universidades

# %%
d=pd.read_csv('data-20230708/w_university_r.csv')

# %%
d
# Out:
#       World Rank                                        Institution  \
# 0              1                                 Harvard University
# 1              2              Massachusetts Institute of Technology
# 2              3                                Stanford University
# 3              4                            University of Cambridge
# 4              5                               University of Oxford
# ...          ...                                                ...
# 1995        1996                           Bharathidasan University
# 1996        1997                     Federal University of Maranhão
# 1997        1998        Jiangxi University of Finance and Economics
# 1998        1999                             University of Tarapacá
# 1999        2000  National Institute of Mental Health and Neuros...
#
#             Location  National Rank Education Rank Employability Rank  \
# 0                USA              1              1                  1
# ...

# %% [markdown]
# ## chile, buscar el research mas alto

# %%
m=d.loc[d.Location=='Chile']
e=m.sort_values('Research Rank',ascending=True)
e.head(20)
# Out:
#       World Rank                                   Institution Location  \
# 1169        1170                       Andrés Bello University    Chile
# 1232        1233                   Austral University of Chile    Chile
# 1376        1377                 University of Santiago, Chile    Chile
# 1420        1421  Pontifical Catholic University of Valparaíso    Chile
# 1448        1449                     University of La Frontera    Chile
# 1623        1624                      University of Valparaíso    Chile
# 1627        1628              Catholic University of the North    Chile
# 1723        1724                     Diego Portales University    Chile
# 1817        1818                Autonomous University of Chile    Chile
# 1855        1856                           University of Talca    Chile
# 1937        1938                      Adolfo Ibáñez University    Chile
# 1998        1999                        University of Tarapacá    Chile
# ...

# %% [markdown]
# ## numero de universidades del peru

# %%
m=d.loc[d.Location=='Peru']
m.head()
m.shape
# Out:
# (2, 9)

# %% [markdown]
# ## encontrar la segunda universidad con miejor scor

# %%
m
# Out:
#       World Rank                             Institution Location  \
# 1505        1506    Cayetano Heredia Peruvian University     Peru
# 1580        1581  Pontifical Catholic University of Peru     Peru
#
#       National Rank Education Rank Employability Rank Faculty Rank  \
# 1505              1              -                  -            -
# 1580              2              -               1339            -
#
#      Research Rank  Score
# 1505          1437   67.7
# 1580          1506   67.3

# %% [markdown]
# ## numero de universidades de cyprus

# %%
m=d.loc[d.Location=='Cyprus']

m.head(20)
# Out:
#       World Rank                      Institution Location  National Rank  \
# 742          743             University of Cyprus   Cyprus              1
# 1728        1729  Cyprus University of Technology   Cyprus              2
#
#      Education Rank Employability Rank Faculty Rank Research Rank  Score
# 742               -                  -            -           703   72.0
# 1728              -                  -            -          1658   66.7

# %%
p=d.loc[d.Location=='Chile']
k=p.sort_values('Research Rank',ascending=False)
k
# Out:
#       World Rank                                   Institution Location  \
# 870          871     Federico Santa María Technical University    Chile
# 822          823                      University of Concepción    Chile
# 430          431                           University of Chile    Chile
# 384          385       Pontifical Catholic University of Chile    Chile
# 1998        1999                        University of Tarapacá    Chile
# 1937        1938                      Adolfo Ibáñez University    Chile
# 1855        1856                           University of Talca    Chile
# 1817        1818                Autonomous University of Chile    Chile
# 1723        1724                     Diego Portales University    Chile
# 1627        1628              Catholic University of the North    Chile
# 1623        1624                      University of Valparaíso    Chile
# 1448        1449                     University of La Frontera    Chile
# ...
